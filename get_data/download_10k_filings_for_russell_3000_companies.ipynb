# %% [markdown]
# This tutorial demonstrates how to download all SEC 10-K filings of Russell 3000 companies that were filed in a given timeframe, for example from 2015 to 2022.
#
# First, we download the CSV file containing all recent holdings of the Russell 3000 index from [ishares.com](https://www.ishares.com/us/products/239714/ishares-russell-3000-etf).
#
# ![img](https://i.imgur.com/qGX0F76l.png)
#
# <!-- The URL of the CSV file is: https://www.ishares.com/us/products/239714/ishares-russell-3000-etf/1467271812596.ajax?fileType=csv&fileName=IWV_holdings&dataType=fund&asOfDate=20221230. -->

# %% [markdown]
# ### Download CSV file with Russell 3000 constituents, convert to DataFrame

# %%
import requests

url = 'https://www.ishares.com/us/products/239714/ishares-russell-3000-etf/1467271812596.ajax?fileType=csv&fileName=IWV_holdings&dataType=fund&asOfDate=20221230'
response = requests.get(url)

with open('russell-3000.csv', 'wb') as f:
    f.write(response.content)

# %% [markdown]
# After opening the CSV file in a text editor, we see that the file is not formatted correctly and needs to be cleaned before conveting the CSV file into a pandas DataFrame. The first 10 lines of metadata show a different structure than the actual holding data, starting at line 11. The file also contains a text block at the end that we need to remove.
#
# <!-- ![incorrect-csv](https://i.imgur.com/fasJMXj.png) -->
# ![incorrect-csv](https://i.imgur.com/IxNALi9.png)
#
# <small>(Metadata, line 1 to 10)</small>
#
# ![incorrect-csv-2](https://i.imgur.com/rF5or5f.png)
#
# <small>(Text block after line 2611)</small>
#
# The metadata section at the beginning and the text block at the end are separated by a seemingly empty row (line 10 and line 2612). Don't get fooled here, because the empty row actually represents the Unicode character `\xa0`. `\xa0` is a non-breaking space character in Unicode encoding. It is also known as a "hard space" or "fixed space" to create a space between words that cannot be broken by line breaks or word wraps.

# %%
# cleaning CSV file
import csv

with open('russell-3000.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    rows = list(reader)

empty_row_indicies = [i for i in range(len(rows)) if (len(rows[i]) == 0 or '\xa0' in rows[i])]

print('Empty rows:', empty_row_indicies)

start = empty_row_indicies[0] + 1
end = empty_row_indicies[1]
cleaned_rows = rows[start:end]

with open('russell-3000-clean.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(cleaned_rows)
# Out:
# Empty rows: [8, 2621]

# %%
import pandas as pd

# load Russell 3000 holdings CSV into a dataframe
holdings = pd.read_csv('./russell-3000-clean.csv')
holdings.head(10)
# Out:
#   Ticker                            Name                  Sector Asset Class  \
# 0   AAPL                       APPLE INC  Information Technology      Equity
# 1   MSFT                  MICROSOFT CORP  Information Technology      Equity
# 2   AMZN                  AMAZON COM INC  Consumer Discretionary      Equity
# 3   BRKB  BERKSHIRE HATHAWAY INC CLASS B              Financials      Equity
# 4  GOOGL            ALPHABET INC CLASS A           Communication      Equity
# 5    UNH          UNITEDHEALTH GROUP INC             Health Care      Equity
# 6   GOOG            ALPHABET INC CLASS C           Communication      Equity
# 7    JNJ               JOHNSON & JOHNSON             Health Care      Equity
# 8    XOM                EXXON MOBIL CORP                  Energy      Equity
# 9    JPM             JPMORGAN CHASE & CO              Financials      Equity
#
#      Market Value  Weight (%)  Notional Value        Shares   Price  \
# 0  559,365,151.11        5.16  559,365,151.11  4,305,127.00  129.93
# 1  513,917,712.42        4.74  513,917,712.42  2,142,931.00  239.82
# 2  213,823,596.00        1.97  213,823,596.00  2,545,519.00   84.00
# 3  159,603,687.60        1.47  159,603,687.60    516,684.00  308.90
# 4  151,996,026.75        1.40  151,996,026.75  1,722,725.00   88.23
# 5  142,028,859.84        1.31  142,028,859.84    267,888.00  530.18
# 6  135,557,878.61        1.25  135,557,878.61  1,527,757.00   88.73
# 7  133,147,817.70        1.23  133,147,817.70    753,738.00  176.65
# 8  130,179,148.40        1.20  130,179,148.40  1,180,228.00  110.30
# 9  112,022,178.30        1.03  112,022,178.30    835,363.00  134.10
#
#         Location                      Exchange Currency  FX Rate  \
# 0  United States                        NASDAQ      USD      1.0
# 1  United States                        NASDAQ      USD      1.0
# 2  United States                        NASDAQ      USD      1.0
# 3  United States  New York Stock Exchange Inc.      USD      1.0
# 4  United States                        NASDAQ      USD      1.0
# 5  United States  New York Stock Exchange Inc.      USD      1.0
# 6  United States                        NASDAQ      USD      1.0
# 7  United States  New York Stock Exchange Inc.      USD      1.0
# 8  United States  New York Stock Exchange Inc.      USD      1.0
# 9  United States  New York Stock Exchange Inc.      USD      1.0
#
#   Market Currency Accrual Date
# 0             USD            -
# 1             USD            -
# 2             USD            -
# 3             USD            -
# 4             USD            -
# 5             USD            -
# 6             USD            -
# 7             USD            -
# 8             USD            -
# 9             USD            -

# %% [markdown]
# ### Download 10-K filings of Russell 3000 constituents
#
# In the next step we download all 10-K filings for each ticker listed in the `holdings` DataFrame.

# %%
# !pip install -q sec-api

# %% [markdown]
# The process looks like this:
# - For each ticker, we download all 10-K URLs in a specified time frame, for example from 2015 to 2022.
# - For each URL, we download the filing and save it to our local disk while creating a new folder for each ticker.
#
# The resulting folder structure is going to look like this:
#
# ![folder-structure](https://i.imgur.com/4E8lCTY.png)
#
# We start with creating batches of tickers, with each batch holding 100 tickers. For example, `[A,B,C,D,E,F]` is converted into `[[A,B,C], [D,E,F]]` with a maximum batch length of 3.

# %%
# create batches of tickers: [[A,B,C], [D,E,F], ...]
# a single batch has a maximum of max_length_of_batch tickers
def create_batches(tickers = [], max_length_of_batch = 100):
  batches = [[]]

  for ticker in tickers:
    if len(batches[len(batches)-1]) == max_length_of_batch:
      batches.append([])

    batches[len(batches)-1].append(ticker)

  return batches


batches = create_batches(list(holdings['Ticker']))

# %% [markdown]
# Next, we define the function `download_10K_metadata(tickers, start_year, end_year)` to download the URLs of the 10-K filings filed by all companies listed in `tickers` in the date range `start_year` and `end_year`.
#
# The complete list of URLs is saved to the file `metadata.csv` on our local disk. Once completed, we can safely re-run `download_10K_metadata()` without having to download all URLs again.

# %%
from sec_api import QueryApi, RenderApi
from pathlib import Path
import multiprocessing

api_key='d567bf389458ee8ab52fd3b4ed983d97643aa97d39748ba1aec53156d592bb8f'

queryApi = QueryApi(api_key=api_key)

def download_10K_metadata(tickers = [], start_year = 2020, end_year = 2023):
  if Path('metadata.csv').is_file():
    result = pd.read_csv('metadata.csv')
    return result

  print('✅ Starting download process')

  # create ticker batches, with 100 tickers per batch
  batches = create_batches(tickers)
  frames = []

  for year in range(start_year, end_year + 1):
    for batch in batches:
      tickers_joined = ', '.join(batch)
      ticker_query = 'ticker:({})'.format(tickers_joined)

      query_string = '{ticker_query} AND filedAt:[{start_year}-01-01 TO {end_year}-12-31] AND formType:"10-K" AND NOT formType:"10-K/A" AND NOT formType:NT'.format(ticker_query=ticker_query, start_year=year, end_year=year)

      query = {
        "query": { "query_string": {
            "query": query_string,
            "time_zone": "America/New_York"
        } },
        "from": "0",
        "size": "200",
        "sort": [{ "filedAt": { "order": "desc" } }]
      }

      response = queryApi.get_filings(query)

      filings = response['filings']

      metadata = list(map(lambda f: {'ticker': f['ticker'],
                                     'cik': f['cik'],
                                     'formType': f['formType'],
                                     'filedAt': f['filedAt'],
                                     'filingUrl': f['linkToFilingDetails']}, filings))

      df = pd.DataFrame.from_records(metadata)

      frames.append(df)

    print('✅ Downloaded metadata for year', year)


  result = pd.concat(frames)
  result.to_csv('metadata.csv', index=False)

  number_metadata_downloaded = len(result)
  print('✅ Downloaded completed. Metadata downloaded for {} filings.'.format(number_metadata_downloaded))

  return result


tickers = list(holdings['Ticker'])

metadata = download_10K_metadata(tickers=tickers, start_year=2021, end_year=2023)
# Out:
# ✅ Starting download process
# ✅ Downloaded metadata for year 2021
# ✅ Downloaded metadata for year 2022
# ✅ Downloaded metadata for year 2023
# ✅ Downloaded completed. Metadata downloaded for 7279 filings.

# %%
metadata.head(10)
# Out:
#   ticker      cik formType                    filedAt  \
# 0   AVGO  1730168     10-K  2021-12-17T16:42:51-05:00
# 1   AMAT     6951     10-K  2021-12-17T16:14:51-05:00
# 2     DE   315189     10-K  2021-12-16T11:39:34-05:00
# 3    ADI     6281     10-K  2021-12-03T16:02:52-05:00
# 4    DIS  1744489     10-K  2021-11-24T16:34:25-05:00
# 5   SBUX   829224     10-K  2021-11-19T16:46:02-05:00
# 6      V  1403161     10-K  2021-11-18T16:06:50-05:00
# 7   QCOM   804328     10-K  2021-11-03T16:06:41-04:00
# 8   AAPL   320193     10-K  2021-10-28T18:04:28-04:00
# 9    ACN  1467373     10-K  2021-10-15T06:54:29-04:00
#
#                                            filingUrl
# 0  https://www.sec.gov/Archives/edgar/data/173016...
# 1  https://www.sec.gov/Archives/edgar/data/6951/0...
# 2  https://www.sec.gov/Archives/edgar/data/315189...
# 3  https://www.sec.gov/Archives/edgar/data/6281/0...
# 4  https://www.sec.gov/Archives/edgar/data/174448...
# 5  https://www.sec.gov/Archives/edgar/data/829224...
# 6  https://www.sec.gov/Archives/edgar/data/140316...
# 7  https://www.sec.gov/Archives/edgar/data/804328...
# 8  https://www.sec.gov/Archives/edgar/data/320193...
# 9  https://www.sec.gov/Archives/edgar/data/146737...

# %%
print('SEC form types:', list(metadata.formType.unique()))
print('Number of filings:', len(metadata))
# Out:
# SEC form types: ['10-K']
# Number of filings: 7279

# %% [markdown]
# ---
#
# Next, we define the function `download_filing(metadata)`. The function creates a new folder for a ticker, removes the iXBRL inline reader parameter from the filing URL with `.replace('ix?doc=/', '')` and downloads the 10-K filing into the newly created folder.

# %%
import os

renderApi = RenderApi(api_key=api_key)

def download_filing(metadata):
  try:
    ticker = metadata['ticker']
    new_folder = "./filings/" + ticker

    if not os.path.isdir(new_folder):
      os.makedirs(new_folder)

    url = metadata['filingUrl'].replace('ix?doc=/', '')
    file_content = renderApi.get_filing(url)
    file_name = url.split("/")[-1]

    with open(new_folder + "/" + file_name, "w") as f:
      f.write(file_content)
  except:
     print('❌ {ticker}: downloaded failed: {url}'.format(ticker=ticker, url=url))

# %%
from tqdm import tqdm

for i in tqdm(range(len(metadata)),desc='Processing'):
    download_filing(metadata.iloc[i])
# Out:
# Processing:  43%|████▎     | 3129/7279 [12:33:39<13270:56:06, 11512.14s/it]
# ❌ PATH: downloaded failed: https://www.sec.gov/Archives/edgar/data/1734722/000173472222000006/path-20220131.htm
# Processing:  44%|████▎     | 3178/7279 [12:35:40<2:16:54,  2.00s/it]

# %%
# downloaded sample filing
download_filing(metadata.iloc[0])
print('✅ Sample 10-K filing downloaded for {}'.format(metadata.iloc[0]['ticker']))
# Out:
# ✅ Sample 10-K filing downloaded for AVGO

# %% [markdown]
# ---
#
# We parallelize the download process in order to use the full bandwidth of the Filings Download API. If we were to use a simple `for` loop to iterate over each filing metadata, we would end up downloading all filings one after another, having to wait around 1 hour for the process to complete.
#
# Time calculation (downloading 1 filing at a time):
# - Time it takes to download a single filing on average: 550 ms
# - Number of filings to download: 6,600
# - Total time = `(6600 * 550ms) / 1000ms / 60sec` = 60 min
#
# Instead, we use [`pandarallel`](https://nalepae.github.io/pandarallel/user_guide/), a library used to apply a function in parallel on all rows or columns in a pandas DataFrame. Launching 4 workers allows us to cut the time from 1 hour down to 15 minutes. A worker downloads one filing while all four workers run in parallel.
#
# Time calculation (downloading 4 filings in parallel):
# - Time it takes to download a single filing on average: 550 ms
# - Number of filings to download: 6,600
# - Total time = `(6600 * 550ms) / 1000ms / 60sec / 4 workers` = 15 min
#
# The figure below illustrates the difference between downloading 1 filing at a time vs downloading 4 filings in parallel.
#
# ![parallelize-python](https://i.imgur.com/b3vAc6ll.png)

# %%
# !pip install -q pandarallel

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.2-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipywidgets) (8.23.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.10 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.10-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.10 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: colorama in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\nishc\documents\github\rag\.venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Downloading ipywidgets-8.1.2-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/139.4 kB ? eta -:--:--
#    ----------------------------------- ---- 122.9/139.4 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 139.4/139.4 kB 1.6 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.10-py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.0 kB ? eta -:--:--
#    ---------------------------------------- 215.0/215.0 kB 6.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.10-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------- ---------------------------- 0.7/2.3 MB 13.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.3/2.3 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.0/2.3 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 14.7 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets
# Successfully installed ipywidgets-8.1.2 jupyterlab-widgets-3.0.10 widgetsnbextension-4.0.10

# %%
import os

# %%
metadata.head(50)
# Out:
#    ticker      cik formType                    filedAt  \
# 0    AVGO  1730168     10-K  2021-12-17T16:42:51-05:00
# 1    AMAT     6951     10-K  2021-12-17T16:14:51-05:00
# 2      DE   315189     10-K  2021-12-16T11:39:34-05:00
# 3     ADI     6281     10-K  2021-12-03T16:02:52-05:00
# 4     DIS  1744489     10-K  2021-11-24T16:34:25-05:00
# 5    SBUX   829224     10-K  2021-11-19T16:46:02-05:00
# 6       V  1403161     10-K  2021-11-18T16:06:50-05:00
# 7    QCOM   804328     10-K  2021-11-03T16:06:41-04:00
# 8    AAPL   320193     10-K  2021-10-28T18:04:28-04:00
# 9     ACN  1467373     10-K  2021-10-15T06:54:29-04:00
# 10   COST   909832     10-K  2021-10-05T20:49:17-04:00
# 11   CSCO   858877     10-K  2021-09-09T16:39:49-04:00
# 12   INTU   896878     10-K  2021-09-08T16:09:57-04:00
# 13     PG    80424     10-K  2021-08-06T16:19:59-04:00
# 14    ADP     8670     10-K  2021-08-04T14:06:37-04:00
# 15   MSFT   789019     10-K  2021-07-29T16:21:55-04:00
# 16    NKE   320187     10-K  2021-07-20T16:11:03-04:00
# 17    MDT  1613103     10-K  2021-06-25T16:51:46-04:00
# 18   ORCL  1341439     10-K  2021-06-21T16:10:31-04:00
# 19    TJX   109198     10-K  2021-03-31T11:20:19-04:00
# 20     HD   354950     10-K  2021-03-24T16:46:14-04:00
# 21    LOW    60667     10-K  2021-03-22T17:06:03-04:00
# 22    WMT   104169     10-K  2021-03-19T16:40:44-04:00
# 23    CRM  1108524     10-K  2021-03-17T16:51:28-04:00
# 24    UNH   731766     10-K  2021-03-01T16:02:27-05:00
# 25    LIN  1707925     10-K  2021-03-01T13:29:25-05:00
# 26    PGR    80661     10-K  2021-03-01T10:23:49-05:00
# 27   NVDA  1045810     10-K  2021-02-26T17:03:14-05:00
# 28      C   831001     10-K  2021-02-26T16:44:10-05:00
# 29     MS   895421     10-K  2021-02-26T16:23:40-05:00
# 30     MO   764180     10-K  2021-02-26T14:45:40-05:00
# 31    EOG   821189     10-K  2021-02-25T16:57:09-05:00
# 32     CB   896159     10-K  2021-02-25T16:51:27-05:00
# 33    MRK   310158     10-K  2021-02-25T16:34:56-05:00
# 34      T   732717     10-K  2021-02-25T16:19:43-05:00
# 35   GILD   882095     10-K  2021-02-25T16:15:23-05:00
# 36    AMT  1053507     10-K  2021-02-25T16:15:20-05:00
# 37    BLK  1364742     10-K  2021-02-25T15:55:29-05:00
# 38    DUK  1326160     10-K  2021-02-25T14:46:09-05:00
# 39    DUK    30371     10-K  2021-02-25T14:46:09-05:00
# 40    CVX    93410     10-K  2021-02-25T14:32:29-05:00
# 41     VZ   732712     10-K  2021-02-25T14:08:10-05:00
# 42    PFE    78003     10-K  2021-02-25T13:59:00-05:00
# 43     KO    21344     10-K  2021-02-25T13:47:17-05:00
# 44     CI  1739940     10-K  2021-02-25T12:24:42-05:00
# 45    DHR   313616     10-K  2021-02-24T19:13:25-05:00
# 46    TMO    97745     10-K  2021-02-24T17:36:20-05:00
# 47   BKNG  1075531     10-K  2021-02-24T17:20:19-05:00
# 48    XOM    34088     10-K  2021-02-24T17:01:02-05:00
# 49    BAC    70858     10-K  2021-02-24T16:56:31-05:00
#
#                                             filingUrl
# 0   https://www.sec.gov/Archives/edgar/data/173016...
# 1   https://www.sec.gov/Archives/edgar/data/6951/0...
# 2   https://www.sec.gov/Archives/edgar/data/315189...
# 3   https://www.sec.gov/Archives/edgar/data/6281/0...
# 4   https://www.sec.gov/Archives/edgar/data/174448...
# 5   https://www.sec.gov/Archives/edgar/data/829224...
# 6   https://www.sec.gov/Archives/edgar/data/140316...
# 7   https://www.sec.gov/Archives/edgar/data/804328...
# 8   https://www.sec.gov/Archives/edgar/data/320193...
# 9   https://www.sec.gov/Archives/edgar/data/146737...
# 10  https://www.sec.gov/Archives/edgar/data/909832...
# 11  https://www.sec.gov/Archives/edgar/data/858877...
# 12  https://www.sec.gov/Archives/edgar/data/896878...
# 13  https://www.sec.gov/Archives/edgar/data/80424/...
# 14  https://www.sec.gov/Archives/edgar/data/8670/0...
# 15  https://www.sec.gov/Archives/edgar/data/789019...
# 16  https://www.sec.gov/Archives/edgar/data/320187...
# 17  https://www.sec.gov/Archives/edgar/data/161310...
# 18  https://www.sec.gov/Archives/edgar/data/134143...
# 19  https://www.sec.gov/Archives/edgar/data/109198...
# 20  https://www.sec.gov/Archives/edgar/data/354950...
# 21  https://www.sec.gov/Archives/edgar/data/60667/...
# 22  https://www.sec.gov/Archives/edgar/data/104169...
# 23  https://www.sec.gov/Archives/edgar/data/110852...
# 24  https://www.sec.gov/Archives/edgar/data/731766...
# 25  https://www.sec.gov/Archives/edgar/data/170792...
# 26  https://www.sec.gov/Archives/edgar/data/80661/...
# 27  https://www.sec.gov/Archives/edgar/data/104581...
# 28  https://www.sec.gov/Archives/edgar/data/831001...
# 29  https://www.sec.gov/Archives/edgar/data/895421...
# 30  https://www.sec.gov/Archives/edgar/data/764180...
# 31  https://www.sec.gov/Archives/edgar/data/821189...
# 32  https://www.sec.gov/Archives/edgar/data/896159...
# 33  https://www.sec.gov/Archives/edgar/data/310158...
# 34  https://www.sec.gov/Archives/edgar/data/732717...
# 35  https://www.sec.gov/Archives/edgar/data/882095...
# 36  https://www.sec.gov/Archives/edgar/data/105350...
# 37  https://www.sec.gov/Archives/edgar/data/136474...
# 38  https://www.sec.gov/Archives/edgar/data/17797/...
# 39  https://www.sec.gov/Archives/edgar/data/17797/...
# 40  https://www.sec.gov/Archives/edgar/data/93410/...
# 41  https://www.sec.gov/Archives/edgar/data/732712...
# 42  https://www.sec.gov/Archives/edgar/data/78003/...
# 43  https://www.sec.gov/Archives/edgar/data/21344/...
# 44  https://www.sec.gov/Archives/edgar/data/173994...
# 45  https://www.sec.gov/Archives/edgar/data/313616...
# 46  https://www.sec.gov/Archives/edgar/data/97745/...
# 47  https://www.sec.gov/Archives/edgar/data/107553...
# 48  https://www.sec.gov/Archives/edgar/data/34088/...
# 49  https://www.sec.gov/Archives/edgar/data/70858/...

# %%
from pandarallel import pandarallel

number_of_workers = 4
pandarallel.initialize(progress_bar=True, nb_workers=number_of_workers, verbose=0)

# uncomment to run a quick sample and download 50 filings
sample = metadata.head(50)
sample.parallel_apply(download_filing, axis=1)

# download all filings
#metadata.parallel_apply(download_filing, axis=1)

print('✅ Download completed')
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=13), Label(value='0 / 13'))), HBox…
# ✅ Download completed
